# %% [markdown]
# Questions and Answers of Assignment 1:
#
# Q1:Explain the key features of Python that makes it popular choice for programming?
#
# Ans1:Python is widely popular for several reasons, and its key features make it a top choice for programming:
#
# a: Readability and Simplicity: Python has a clean and easy-to-read syntax, making it beginner-friendly. Its structure mimics plain English, which reduces the learning curve and improves code readability.
# b:Interpreted Language: Python is an interpreted language, meaning code is executed line by line, which simplifies debugging and allows for interactive testing.
# c:Extensive Standard Library: Python has a vast collection of libraries and modules for various tasks like file handling, web development, data analysis, machine learning, and more. This reduces the need to write code from scratch.
# d:Cross-Platform Compatibility: Python is cross-platform, meaning it can run on different operating systems (Windows, macOS, Linux) without modification.
# e:Dynamic Typing: Python is dynamically typed, so you don’t need to declare the data type of a variable. This increases flexibility and simplifies the code.
# f:Object-Oriented and Functional Programming: Python supports both object-oriented and functional programming paradigms, allowing developers to choose the style that best suits their needs.
# g:Strong Support for Data Science and AI: Python's popularity has surged in fields like data science, machine learning, and artificial intelligence due to libraries like NumPy, pandas, TensorFlow, and Scikit-learn.
#
#
#
#
# Q2: Describe the role of predefined keywords in Python and provide examples of how they are used in a  program?
#
# ANS2: In Python, predefined keywords (also known as reserved words) are part of the language's syntax and have specific meanings. These keywords cannot be used as identifiers (like variable names, function names, or any other names) because they are reserved for defining the structure and control flow of the program.
#
# Role of Predefined Keywords:
# 1:Control the Flow of a Program: Keywords such as if, else, while, and for are used to create conditional statements and loops.
# 2:Define Functions, Classes, and Variables: Keywords like def, class, and global help in defining functions, classes, and controlling the scope of variables.
# 3:Handle Exceptions: Keywords like try, except, and finally are used for exception handling.
# 4:Work with Data Structures: Keywords like True, False, None represent Boolean values and null values, respectively.
# 5:Memory Management: Keywords such as del are used to free up memory by removing references to objects.
# Examples of Predefined Keywords in Use:
# 1: Conditional Statements:
# Here, the if and else keywords are used to make a decision based on the value of x.
# 2:Looping with for:The for keyword is used to iterate over the sequence generated by range(3).
# 3:Function Definition with def:
# The def keyword defines the function greet, which returns a greeting message.
# 4:Handling Exceptions:
# The try, except, and finally keywords manage exceptions and ensure the program handles errors gracefully.
#
#
# Q3:Compare and contrast mutable and immutable objects in Pythojn with examples?
#
# ANS3:In Python, objects are classified as either mutable or immutable based on whether their state (or content) can be changed after they are created. This distinction impacts how objects behave when they are modified.
#
# Mutable Objects:
# Definition: Mutable objects are those whose values or state can be changed after creation.
# Examples: Lists, dictionaries, sets, and byte arrays.
# In this example, the list my_list was changed after creation by modifying the first element.
#
# Immutable Objects:
# Definition: Immutable objects are those whose values or state cannot be changed once they are created.
# Examples: Integers, floats, strings, tuples, frozensets.
#
# In the case of the list (mutable), modifying one reference affects the other. In the case of the tuple (immutable), modification results in a new object without affecting the original.
#
#
#
#
#
#
# Q4:Discuss the different types of operators in Python and provide examples of how they are used/
#
# ANS4: In Python, operators are special symbols that perform operations on variables and values. They are divided into several categories:
#
# 1. Arithmetic Operators
# These operators are used to perform basic mathematical operations.
# + : Addition
# - : Subtraction
# * : Mulitplication
# / : Division
# //: Floor Division
# % : Modulus
#
# 2. Comparison (Relational) Operators
# These operators are used to compare values. They return either True or False.
#
# == : equal to
# != : not equal to
# >  : Greater than
# <  : Less than
# >= : Greater than equal to
# <= : less than edqual to
#
# 3: Logical Operators:
# Logical operators are used to combine conditional statements.
#
# 4: Bitwise Operators:
# These operators perform operations on bits (binary values). They are mostly used in low-level programming.
#
#
#
#
# Q5: Explain the concept of type casting in Python with examples?
#
# ANS5: Type casting (or type conversion) in Python is the process of converting one data type to another. Python provides several built-in functions for type casting to ensure that variables are treated as a specific data type when needed.
# Two type of types casting are:
# 1: Implicit Type Casting: Python automatically converts one data type to another without user intervention.
# 2: Explicit Type Casting: The user manually converts one data type to another using casting functions.
#
# 1: Python automatically converts a smaller data type to a larger data type to prevent data loss.
# For example, when an integer is added to a float, Python automatically converts the integer to a float before performing the addition.
# 2:In explicit type casting, the user converts the data type explicitly by using built-in functions.
#
# Python provides several functions for explicit type conversion:
#
# int(): Converts a value to an integer.
# float(): Converts a value to a float.
# list(): Converts a value to a list.
# tuple(): Converts a value to a tuple.
# set(): Converts a value to a set.
#
# Q6: How do conditional statements work in Python? Illustrate with examples?
#
# ANS6:Conditional statements in Python are used to execute code blocks based on whether a given condition is true or false. These conditions typically involve comparison or logical expressions. Python supports several types of conditional statements: if, else, and elif (short for "else if").
# 1: The if statement executes a block of code if a condition is true.
# 2: The else statement is used to specify a block of code that will run if the if condition is false.
# 3: The elif (short for "else if") allows you to check multiple conditions. It is used after an if statement and before an else statement. If the initial if condition is false, Python checks the elif conditions in sequence. If none of the if or elif conditions are true, the else block is executed.
#
# Q7:Describe the different types of loops in Python and their use cases with examples.
#
#
# ANS7:In Python, loops are used to execute a block of code repeatedly until a certain condition is met. Python supports two types of loops: for loop and while loop. Each loop has different use cases, and they can be used with control statements like break, continue, and pass to modify the loop's behavior.
#
# 1:The for loop in Python is used to iterate over a sequence (such as a list, tuple, string, or range). It is used when the number of iterations is known or when you need to iterate over each element in a sequence.
# Uses Cases:
# Iterating over a collection of items (like lists, tuples, or dictionaries).
# Repeating a block of code a specific number of times.
# Performing actions on every element of a sequence.
#
# 2:The while loop executes a block of code as long as a specified condition is true. It is useful when the number of iterations is not known beforehand, and the loop depends on a condition being met.
#
# Uses Cases:
# 1:When the number of iterations is not fixed and depends on dynamic conditions.
# 2:Reading input or processing tasks until a specific event occurs.
# 3:Continuously polling for events or conditions.
#
# 3. Control Statements in Loops
# a. break Statement
# The break statement is used to terminate the loop prematurely when a certain condition is met. It is used to exit the loop even if the iteration is not complete.
# b. continue Statement
# The continue statement skips the current iteration and proceeds to the next one. It is used to skip certain values or conditions in the loop without terminating the entire loop.
# c. pass Statement
# The pass statement does nothing and is used as a placeholder in loops or conditionals where you may have future code but want to avoid syntax errors.
