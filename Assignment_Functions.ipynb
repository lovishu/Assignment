# %% [markdown]
#  Questions and Answers
#
#  Q1. What is the difference between a function and a method in Python?
#
# Ans 1. function is a block of reusable code that is not tied to any object.
#
# def greet(name):
#     return f"Hello, {name}!"
#
# print(greet("Alice"))
#
#
# A method is a function that is associated with an object (i.e., it is part of a class).
#
# class Person:
#     def greet(self, name):
#         return f"Hello, {name}!"
#
# p = Person()
# print(p.greet("Bob"))
#
# Q2.  2. Explain the concept of function arguments and parameters in Python.
#
# Ans2. In Python, parameters and arguments are terms related to functions, but they refer to different concepts:
#
# These are placeholders defined in the function definition.
#
# They specify what kind of arguments the function expects when it is called.
#
# Q3. What are the different ways to define and call a function in Python?
#
# Ans3. Using the def keyword.
#
# python
# Copy
# Edit
#
#
# def add(a, b):
#     return a + b
# 2. Lambda (Anonymous) Function
#
#
# add = lambda a, b: a + b
#
# def outer():
#     def inner():
#         print("Inner function")
#     inner()
# 4. Using functools.partial()
#
# from functools import partial
#
# def multiply(x, y):
#     return x * y
#
# double = partial(multiply, 2)
#
#  4. What is the purpose of the `return` statement in a Python function?
#
#  Ans 4. The return statement in a Python function is used to exit the function and send a result (value) back to the caller.
#  def square(x):
#     return x * x
#
# result = square(5)  # result = 25
#
# Once return is executed, the function stops, and any code after it is not run.
#
# python
# Copy
# Edit
#
#
# def example():
#     return "Done"
#     print("This will not execute")
#
#
#
# def stats(x, y):
#     return x + y, x * y
#
# sum_, product = stats(2, 3)  # sum_ = 5, product = 6
#
#
# Can return multiple values as a tuple
#
# python
# Copy
# Edit
# def stats(x, y):
#     return x + y, x * y
#
# sum_, product = stats(2, 3)  # sum_ = 5, product = 6
#
# Q5. 5. What are iterators in Python and how do they differ from iterables?
#
# Ans5. nums = [1, 2, 3]     # list is iterable
# for n in nums:
#     print(n)
#
#
# An iterator is the object that produces values one at a time from an iterable.
#
# nums = [1, 2, 3]
# it = iter(nums)     # Get iterator from iterable
#
# print(next(it))     # 1
# print(next(it))     # 2
# print(next(it))     # 3
# # print(next(it))   # Raises StopIteration
#
# Q6. Explain the concept of generators in Python and how they are defined.
#
# Ans6. A generator is a special type of iterator that yields values one at a time, on demand, using the yield keyword instead of return. They are memory-efficient and ideal for working with large datasets or infinite sequences.
#
# def count_up_to(n):
#     count = 1
#     while count <= n:
#         yield count
#         count += 1
# Q7. What are the advantages of using generators over regular functions?
#
# Ans7.🔹 1. Memory Efficiency
# Generators yield items one at a time using the yield keyword, which means they don’t store the entire result in memory. This is especially useful when dealing with large data streams.
#
# Lazy Evaluation:
#  Generators compute values on the fly. They only produce the next value when requested, reducing computation time and improving responsiveness.
#
# Improved Performance:
# Since they don't compute all values at once and avoid storing large data structures in memory, generators often perform faster in terms of startup time and resource usage.
#
# Q8. What is a lambda function in Python and when is it typically used?
# Ans8. A lambda function in Python is an anonymous (unnamed) function defined using the lambda keyword. It can have any number of arguments but only one expression, which is evaluated and returned.
#
# add = lambda x, y: x + y
# print(add(2, 3))  # Output: 5
#
#
#
# names = ['Alan', 'Greg', 'Tom']
# names.sort(key=lambda x: len(x))  # Sort by length of name
#
#
# Q9. 9. Explain the purpose and usage of the `map()` function in Python.
#
# Ans9. The map() function in Python is used to apply a function to every item in an iterable (like a list, tuple, etc.), returning a new iterable (specifically a map object) with the results.
#
# map(function, iterable)
# a = [1, 2, 3]
# b = [4, 5, 6]
# result = list(map(lambda x, y: x + y, a, b))
# print(result)  # Output: [5, 7, 9]
#
# Q10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# Amns10. The map(), reduce(), and filter() functions in Python all work with iterables, but they serve different purposes and operate differently. Here's a breakdown of each function:
#
# 1. map():
# Purpose: Applies a function to every item in the iterable and returns a new iterable (map object) containing the results.
#
# nums = [1, 2, 3, 4]
# squared = list(map(lambda x: x**2, nums))
# print(squared)  # Output: [1, 4, 9, 16]
#
# Q11.11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given  list:[47,11,42,13];
#
# An11.To understand the internal mechanism of the reduce() function, let's walk through the sum operation step by step for the list [47, 11, 42, 13].
#
# The reduce() function takes a binary function (like addition lambda x, y: x + y) and applies it cumulatively to the items in the list.
#
# Step 1: 47 + 11 = 58
# Step 2: 58 + 42 = 100
# Step 3: 100 + 13 = 113
#
#
#
#
# Practical Questions
#
#
#
#
# Q1.Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list
#
# Ans1. def sum_of_even_numbers(numbers):
#     # Use a list comprehension to filter even numbers and sum them
#     return sum(x for x in numbers if x % 2 == 0)
#
# # Example usage:
# numbers = [1, 2, 3, 4, 5, 6, 7, 8]
# result = sum_of_even_numbers(numbers)
# print(result)  # Output: 20 (2 + 4 + 6 + 8)
#
#
# Q2. Create a Python function that accepts a string and returns the reverse of that string.
#
#
#
# Ans 2. def reverse_string(input_string):
#     return input_string[::-1]
#
# # Example usage:
# string = "Hello, World!"
# result = reverse_string(string)
# print(result)  # Output: !dlroW ,olleH
#
#
#
# Q3.  3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number
#
# An3. def square_numbers(numbers):
#     return [x ** 2 for x in numbers]
#
# # Example usage:
# numbers = [1, 2, 3, 4, 5]
# squared_numbers = square_numbers(numbers)
# print(squared_numbers)  # Output: [1, 4, 9, 16, 25]
#
#
# Q4.  Write a Python function that checks if a given number is prime or not from 1 to 200.
#
# Ans4. def is_prime(number):
#     if number <= 1:
#         return False
#     for i in range(2, int(number ** 0.5) + 1):
#         if number % i == 0:
#             return False
#     return True
#
# # Example usage:
# for num in range(1, 201):
#     if is_prime(num):
#         print(num, "is prime")
#
# Q5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
#
# Ans5. class FibonacciIterator:
#     def __init__(self, limit):
#         self.limit = limit  # The upper limit for the Fibonacci sequence
#         self.a, self.b = 0, 1  # Starting values of the Fibonacci sequence
#
#     def __iter__(self):
#         return self
#
#     def __next__(self):
#         if self.a > self.limit:
#             raise StopIteration  # Stop when the value exceeds the specified limit
#         else:
#             current = self.a
#             self.a, self.b = self.b, self.a + self.b  # Update the Fibonacci sequence
#             return current
#
# # Example usage:
# fibonacci_sequence = FibonacciIterator(100)  # Generate Fibonacci sequence up to 100
# for num in fibonacci_sequence:
#     print(num)
#
# Q6.  6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
#
# Ans6. def powers_of_two(exponent):
#     for i in range(exponent + 1):
#         yield 2 ** i
#
# # Example usage:
# for power in powers_of_two(5):
#     print(power)
#
#
# Q7.Implement a generator function that reads a file line by line and yields each line as a string.
#
# Ans7.def read_file_line_by_line(file_path):
#     with open(file_path, 'r') as file:
#         for line in file:
#             yield line.strip()  # Strip to remove any leading/trailing whitespace or newline characters
#
# # Example usage:
# file_path = 'example.txt'  # Replace with the path to your file
# for line in read_file_line_by_line(file_path):
#     print(line)
#
# Q8. 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
#
#
# Ans8. # List of tuples
# tuples_list = [(1, 3), (2, 2), (4, 1), (3, 4)]
#
# # Sorting the list using a lambda function to sort by the second element of each tuple
# sorted_list = sorted(tuples_list, key=lambda x: x[1])
#
# # Output the sorted list
# print(sorted_list)
#
# Q9.Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
#
# Ans9. def celsius_to_fahrenheit(celsius):
#     return (celsius * 9/5) + 32
#
# # List of temperatures in Celsius
# celsius_temperatures = [0, 25, 30, 100, -5]
#
# # Using map() to convert the list of Celsius temperatures to Fahrenheit
# fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))
#
# # Output the Fahrenheit temperatures
# print(fahrenheit_temperatures)
